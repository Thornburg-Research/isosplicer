# %%
import os

# %%
# gtfFile = '/home/zane/Data/human_genome/ncbi_dataset40/ncbi_dataset/data/GCF_000001405.40/genomic.gtf'
gtfFile = '/home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf'

# %%
outputDir = './GCF_000001405.38/'

# %%
human_chromosomes = ['NC_000001.11','NC_000002.12','NC_000003.12','NC_000004.12','NC_000005.10',
 'NC_000006.12','NC_000007.14','NC_000008.11','NC_000009.12','NC_000010.11',
'NC_000011.10','NC_000012.12','NC_000013.11','NC_000014.9','NC_000015.10',
'NC_000016.10','NC_000017.11','NC_000018.10','NC_000019.10','NC_000020.11',
'NC_000021.9','NC_000022.11','NC_000023.11','NC_000024.10']

# %%
try:
    os.mkdir(outputDir)
except:
    print('Could not make output directory')

# %%
for idx, chromo in enumerate(human_chromosomes):
    command = f'grep \'{chromo.replace('_','\\_')}\' {gtfFile} > {outputDir}chr{int(idx+1)}.gtf'
    print(command)
    os.system(command)
# Out:
# grep 'NC\_000001.11' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr1.gtf
# grep 'NC\_000002.12' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr2.gtf
# grep 'NC\_000003.12' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr3.gtf
# grep 'NC\_000004.12' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr4.gtf
# grep 'NC\_000005.10' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr5.gtf
# grep 'NC\_000006.12' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr6.gtf
# grep 'NC\_000007.14' /home/zane/Data/human_genome/ncbi_dataset/data/GCF_000001405.38/genomic.gtf > ./GCF_000001405.38/chr7.gtf
# ...
